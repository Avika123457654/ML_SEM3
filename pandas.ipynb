# %%
! pip3 install pandas

# %%
import pandas as pd
import numpy as np

# %%
restaurant_data = {
    'Table_No.' : [12,14,15],
    'Bill_Amount' : [1250,890,2400],
    'Waiter_Name' : ['Amit','Priya','Rahul']
}
df= pd.DataFrame(restaurant_data)
print(df)

# %%
orders = pd.Series(
    [45, 15, 60, 30],
    index=["pizza", "pasta", "fries", "burger"]
)

print(orders)
print("Pizza orders:", orders["pizza"])

# %%
orders = pd.Series(
    [45, 15, 60, 30],
    index=["pizza", "pasta", "fries", "burger"]
)

print(orders)
print("Pizza orders:", orders["pizza"])

# %%
22
